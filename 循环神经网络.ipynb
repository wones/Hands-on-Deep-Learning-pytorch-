# %% [markdown]
# # 含隐藏状态的循环神经网络

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 隐藏状态中XtWxh+Ht-1Whh的计算等价于 Xt与Ht-1 连结后的矩阵乘以Wxh 与Whh连 结 后 的 矩 阵

# %%
import torch
X,W_xh=torch.randn(3,1),torch.randn(1,4)
H,W_hh=torch.randn(3,4),torch.randn(4,4)
torch.mm(X,W_xh)+torch.mm(H,W_hh)
# Out:
# tensor([[-2.7935,  1.8573, -1.9301, -3.8419],
#         [ 0.5958,  1.3353, -1.5439, -1.9615],
#         [ 1.2929, -2.1545,  1.8170,  2.5044]])

# %%
torch.matmul(torch.cat((X,H),dim=1),torch.cat((W_xh,W_hh),dim=0))
# Out:
# tensor([[-2.7935,  1.8573, -1.9301, -3.8419],
#         [ 0.5958,  1.3353, -1.5439, -1.9615],
#         [ 1.2929, -2.1545,  1.8170,  2.5044]])

# %% [markdown]
# # 应用：基于字符级循环神经网络的语言模型

# %% [markdown]
# ![image.png](attachment:image.png)
